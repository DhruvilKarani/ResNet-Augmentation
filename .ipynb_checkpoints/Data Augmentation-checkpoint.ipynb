# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
from torchvision.datasets import CIFAR10
from torchvision import transforms
from torchvision.transforms import Compose
import sys
import os
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import random
import sys
sys.path.append("../models")
from models.resnet import ResNet

# %%
device = "cpu"

if torch.cuda.is_available():
    device = "cuda"

print(device)
# Out:
# cuda

# %%
train_transform = Compose([
    transforms.RandomCrop(32, padding=4)
])

# %%
cifar10_train = CIFAR10(root = "/data", train=True, download = True, transform=train_transform)
train_loader = torch.utils.data.DataLoader(cifar10_train, batch_size=100, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
cifar10 = CIFAR10(root = "/data", train=True, download = True)

y = cifar10.targets
X = cifar10.data


print(X.shape)
# Out:
# Files already downloaded and verified
# (50000, 32, 32, 3)

# %%
cifar10_test = CIFAR10(root = "/data", train=False, download = True)
test_loader = torch.utils.data.DataLoader(cifar10_test, batch_size=100, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
Counter(y)

#uniform distribution
# Out:
# Counter({6: 5000,
#          9: 5000,
#          4: 5000,
#          1: 5000,
#          2: 5000,
#          7: 5000,
#          8: 5000,
#          3: 5000,
#          5: 5000,
#          0: 5000})

# %%
cifar10.class_to_idx
# Out:
# {'airplane': 0,
#  'automobile': 1,
#  'bird': 2,
#  'cat': 3,
#  'deer': 4,
#  'dog': 5,
#  'frog': 6,
#  'horse': 7,
#  'ship': 8,
#  'truck': 9}

# %%
def show_example(X, y, label, grid = (3,3)):
    y_label = [i for i, tag in enumerate(y) if label == tag]
    random.shuffle(y_label)
    
    rows = grid[0]
    columns = grid[1]
    
    fig, axes = plt.subplots(rows, columns)
    fig.set_figheight(7)
    fig.set_figwidth(7)
 
    for row in axes:
        for col in row:
            col.imshow(X[y_label.pop()])
    plt.show()

# %%
#airplane
show_example(X, y, 0)

# %%
#automobile
show_example(X, y, 1)

# %%
#frog
show_example(X, y, 6)

# %%
#deer
show_example(X, y, 4)

# %%
# class SimpleNet(nn.Module):
#     def __init__(self, n_classes):
#         super(SimpleNet, self).__init__()
#         self.classes = n_classes
#         self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=(3,3), stride=1, padding=1)
#         self.relu = nn.ReLU()
#         self.maxpool = nn.MaxPool2d(2)
#         self.conv2 = nn.Conv2d(in_channels=6, out_channels=6, kernel_size=(5,5), stride=1, padding=1)
#         self.conv3 = nn.Conv2d(in_channels=6, out_channels=6, kernel_size=(5,5), stride=1, padding=1)
#         self.bn3 = nn.BatchNorm2d(6)
#         self.bn2 = nn.BatchNorm2d(6)
#         self.bn1 = nn.BatchNorm2d(6)
#         self.fc1 = nn.Linear(4704, 100)
#         self.fc2 = nn.Linear(100, 50)
#         self.fc3 = nn.Linear(50, 10)
    
#     def forward(self, X):
#         output = self.conv1(X)
#         output = self.bn1(output)
#         output = self.relu(output)
#         output = self.conv2(output)
#         output = self.bn2(output)
#         output = self.relu(output)
#         output = self.conv3(output)
#         output = self.bn3(output)
#         output = self.relu(output)
#         output = output.view(-1, 4704)
#         output = self.fc1(output)
#         output = self.relu(output)
#         output = self.fc2(output)
#         output = self.relu(output)
#         output = self.fc3(output)
#         return output

# %%
model = ResNet(32, 10)

# %%
test_input = torch.FloatTensor(X[0:1]).permute(0,3,2,1)
output = model(test_input)

# %%
# TRAIN_SIZE = 0.7

# idxs = list(range(len(y)))
# random.shuffle(idxs)

# train_idxs = idxs[:int(len(y)*TRAIN_SIZE)]
# test_idxs = idxs[int(len(y)*TRAIN_SIZE):]

# X_train = torch.FloatTensor(X).permute(0,3,2,1)
# y_train = torch.LongTensor(y)

# %%
# print("Train data shape: ", X_train.shape)

# %%
# X_test = torch.FloatTensor(X_test).permute(0,3,2,1)
# y_test = torch.LongTensor(y_test)

# %%
# print("Test data shape: ", X_test.shape)

# %%
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()
LR = 0.001
optim = torch.optim.Adam(model.parameters(), lr = LR)

# %%
EPOCHS = 13
epoch_loss = []
val_loss = []

# %%
for i in range(EPOCHS):
    ep = 0
    model.train()
    for X_b, y_b in train_loader:
        optim.zero_grad()

        X_b = X_b.to(device).permute(0,3,2,1)
        y_b = y_b.to(device)

        output = model(X_b)

        loss = loss_fn(output, y_b)

        loss.backward()
        ep += loss.item()
        optim.step()
    print("Epoch {0}: {1}".format(i+1, round(ep,2)))
    epoch_loss.append(ep)
    
    correct = 0
    val = 0
    model.eval()
    for X_b, y_b in test_loader:
        X_b = X_b.to(device)
        y_b = y_b.to(device)
        output = model(X_b)
        loss = loss_fn(output, y_b)
        val += loss.item()
        probs = torch.functional.F.softmax(output, 1)
        label = torch.argmax(probs, dim=1)
        correct += torch.sum(label == y_b).item()
    val_loss.append(val)

    print("Accuracy: ", round(correct/10000,2), "Loss: ", round(val,1))
# Out:
# Epoch 1: 987.16
# Accuracy:  0.51 Loss:  136.4
# Epoch 2: 594.53
# Accuracy:  0.56 Loss:  124.9
# Epoch 3: 506.02
# Accuracy:  0.62 Loss:  112.7
# Epoch 4: 432.7
# Accuracy:  0.67 Loss:  100.0
# Epoch 5: 383.19
# Accuracy:  0.7 Loss:  93.0
# Epoch 6: 337.77
# Accuracy:  0.69 Loss:  100.5
# Epoch 7: 304.06
# Accuracy:  0.7 Loss:  102.6
# Epoch 8: 261.29
# Accuracy:  0.71 Loss:  111.1
# Epoch 9: 244.4
# Accuracy:  0.71 Loss:  118.9
# Epoch 10: 223.33
# Accuracy:  0.71 Loss:  120.6
# Epoch 11: 212.2
# Accuracy:  0.72 Loss:  130.7
# Epoch 12: 197.58
# Accuracy:  0.71 Loss:  152.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-79c694c90d47> in <module>
#       8         y_b = y_b.to(device)
#       9
# ---> 10         output = model(X_b)
#      11
#      12         loss = loss_fn(output, y_b)
#
# ...

# %%
plt.plot(np.array(epoch_loss))
plt.plot(np.array(val_loss))

# %%
Counter([i.item() for i in y_test])

# %%
import torch
A = torch.randn(64, 15, 15)
B = torch.randn(15, 15)
C = A.matmul(B)

# %%
A.permute(2, 1, 0).shape

# %%
B.shape

# %%
C.shape

# %%
t4d = torch.empty(3, 3, 4, 2)

# %%
t4d[:2, :2, :, :].shape
